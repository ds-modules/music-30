# %%
import collections
import numpy as np

with open("/Users/joelchang/Desktop/Downloads/alice_oz.txt", 'r') as f:
    text = f.readline()
splitText = text.split()

NPREF = 2
NONWORD = "\n"
MAXGEN = 200

class Prefix:
    
    def __init__(self, n, string):
        self.__multiplier = 31
        self.p = collections.deque()
        
        for i in range(n):
            self.p.append(string)
        
    def __hash__(self):
        h = 0
        for i in range(len(self.p)):
            h = self.__multiplier * h + hash(self.p[i])
        return h
    
    def __eq__(self, other):
        for i in range(len(self.p)):
            if (self.p[i] != other.p[i]):
                return False
        return True
    
    def clone(self):
        copyP = self.p.copy()
        copy = Prefix(NPREF, NONWORD)
        copy.p = copyP
        return copy
    
class Chain:
    def __init__(self, NPREF=2, NONWORD = "\n", MAXGEN = 200):
        # map<Prefix, vector<string>>
        self.statetab = {}
        self.NPREF = NPREF
        self.NONWORD = NONWORD
        self.MAXGEN = MAXGEN
        
        self.prefix = Prefix(self.NPREF, self.NONWORD)

    def add(self, string):
        suf =  self.statetab.get(self.prefix)
        if not suf:
            suf = []
            self.statetab[self.prefix.clone()] = suf
            
        suf.append(string)
        self.prefix.p.popleft()
        self.prefix.p.append(string)
        

    def build(self, inStream):
        for i in inStream:
            self.add(i)
        self.add(self.NONWORD)

    def generate(self, nwords):
        chain = []
        new = Prefix(self.NPREF, self.NONWORD)
        for i in range(0, nwords):
            s = self.statetab.get(new)
            
            if not s:
                return "No state"

            r = np.random.randint(0, 9999999999) % len(s)
            word = s[r]

            if word == self.NONWORD:
                break;
            chain.append(word)
            new.p.popleft()
            new.p.append(word)
        return chain

# %%
c = Chain()
c.build(splitText)

# %%
' '.join(c.generate(30))
# Out:
# ''

# %% [markdown]
# -----

# %%
import pandas as pd
df = pd.read_csv('/Users/joelchang/Desktop/Downloads/bach_choral_set_dataset.csv')

# %%
df['choral_ID'].unique()
# Out:
# array(['000106b_', '000206b_', '000306b_', '000408b_', '000507b_',
#        '000606b_', '000707b_', '000907b_', '001007b_', '001106b_',
#        '001207b_', '001306b_', '001606b_', '001707b_', '001805b_',
#        '001907ch', '002406bs', '002506b_', '002806b_', '002908ch',
#        '003006b_', '003109b_', '003206b_', '003306b_', '003608b2',
#        '003806b_', '003907b_', '003907bv', '004006b_', '004008b_',
#        '005708b_', '012006b_', '012106b_', '012206b_', '012306b_',
#        '012406b_', '012506b_', '012606b_', '012606bv', '012705b_',
#        '012805b_', '013506b_', '013705ch', '013906b_', '014007b_',
#        '014403b_', '014406b_', '014500ba', '014505b_', '014505bv',
#        '014608b_', '014806b_', '014806bv', '015105b_', '015301b_',
#        '015305b_', '015309b_', '015403b_', '015408b_', '015505b_'],
#       dtype=object)

# %% [markdown]
# These three chains are trained on each chorale (entire dataset).

# %%
chord = Chain()
meter = Chain()
bass = Chain()
for chorale in df['choral_ID'].unique():
    d = df[df['choral_ID'] == chorale]
    chord.build(d['chord_label'])
    
    bass.build(d['bass'])
    
    chorale_meter_str = np.array(d['meter'], dtype='str')
    meter.build(chorale_meter_str)
    
print(' '.join(chord.generate(10)))
print(' '.join(bass.generate(10)))
print(' '.join(meter.generate(10)))
# Out:
# F_M BbM BbM F_M F_M7 BbM BbM F_M F_M G_m
# F D E E B F# F# D E E
# 3 2 5 3 4 3 5

# %% [markdown]
# -------
#
# Install music21, listen to the first MIDI file `jsb/000106b.mid` (the miniplayer doesn't show up in jupyterlab).

# %%
#!pip install music21
from music21 import midi

path = "/Users/joelchang/Desktop/Downloads/notebooks_nb2_jsb_000106b_.midi"
mf = midi.MidiFile()
mf.open(path) # path='abc.midi'
mf.read()
mf.close()
s = midi.translate.midiFileToStream(mf)
s.show('midi')
# Out:
#                 <div id='midiPlayerDiv7760'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv7760');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# Creating a markov chain for the chord, bass, and meter.

# %%
chord = Chain()
meter = Chain()
bass = Chain()

# train on one chorale first
d = df[df['choral_ID'] == '000106b_']

# build chord markov chain
chord.build(d['chord_label'])

# build bass markov model
bass.build(d['bass'])

# convert meter to strings, build meter markov model
chorale_meter_str = np.array(d['meter'], dtype='str')
meter.build(chorale_meter_str)

# %%
chords_generated = chord.generate(20)
print(chords_generated)
bass_generated = bass.generate(20)
print(bass_generated)
meter_generated = meter.generate(20)
print(meter_generated)
# Out:
# ['F_M', 'C_M', 'C_M', 'F_M', 'F_M', 'BbM', 'BbM', 'F_M', 'F_M', 'C_M', 'C_M', 'F_M', 'C_M4', 'C_M4', 'C_M4', 'C_M4', 'C_M4', 'C_M', 'F_M', 'F_M']
# ['F', 'E', 'E', 'F', 'F', 'F', 'Bb', 'Bb', 'A', 'C', 'C', 'C', 'Bb', 'Bb', 'Bb', 'C', 'C', 'C', 'C', 'F']
# ['3', '5', '2', '3', '2', '5', '2', '3', '2', '5', '2', '1', '3', '4', '3', '5', '2', '1', '3', '2']

# %%
# middle C
bass_converter = {'C': 60, 
                 'D': 62,
                 'E': 64,
                 'F': 65,
                 'G': 67,
                 'A': 69,
                 'B': 71
                 }
# starting with C2
lower_octave_bass_converter = {'C': 36, 
                             'D': 38,
                             'E': 40,
                             'F': 41,
                             'G': 43,
                             'A': 45,
                             'B': 47
}

# %%
bass_midi_notes = []
for i in bass_generated:
    bass_midi_notes.append(lower_octave_bass_converter[i])
bass_midi_notes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-bef00b6d1d70> in <module>
#       1 bass_midi_notes = []
#       2 for i in bass_generated:
# ----> 3     bass_midi_notes.append(lower_octave_bass_converter[i])
#       4 bass_midi_notes
#
# KeyError: 'Bb'

# %% [markdown]
# ------
#
# **the code below can be ignored, this is mainly testing if the underlying data structure is the same after adding more chords from a new chorale to a pre-existing chain.**

# %%
first = df[df['choral_ID'] == '000106b_']
first.head(10)
# Out:
#   choral_ID  event_number pitch_1 pitch_2 pitch_3 pitch_4 pitch_5 pitch_6  \
# 0  000106b_             1     YES      NO      NO      NO      NO     YES
# 1  000106b_             2     YES      NO      NO      NO     YES      NO
# 2  000106b_             3     YES      NO      NO      NO     YES      NO
# 3  000106b_             4     YES      NO      NO      NO      NO     YES
# 4  000106b_             5     YES      NO      NO      NO      NO     YES
# 5  000106b_             6      NO      NO     YES      NO      NO     YES
# 6  000106b_             7      NO      NO     YES      NO      NO     YES
# 7  000106b_             8     YES      NO      NO      NO      NO     YES
# 8  000106b_             9     YES      NO      NO      NO      NO     YES
# 9  000106b_            10      NO      NO     YES      NO      NO     YES
#
#   pitch_7 pitch_8 pitch_9 pitch_10 pitch_11 pitch_12 bass  meter chord_label
# 0      NO      NO      NO      YES       NO       NO    F      3         F_M
# 1      NO     YES      NO       NO       NO       NO    E      5         C_M
# 2      NO     YES      NO       NO       NO       NO    E      2         C_M
# 3      NO      NO      NO      YES       NO       NO    F      3         F_M
# 4      NO      NO      NO      YES       NO       NO    F      2         F_M
# 5      NO      NO      NO      YES       NO       NO    D      4         D_m
# 6      NO      NO      NO      YES       NO       NO    D      2         D_m
# 7      NO      NO      NO      YES       NO       NO    A      3         F_M
# 8      NO      NO      NO      YES       NO       NO    A      2         F_M
# 9      NO      NO      NO       NO      YES       NO   Bb      5         BbM

# %%
df[df['chord_label'] == "F_m7"]
# Out:
#      choral_ID  event_number pitch_1 pitch_2 pitch_3 pitch_4 pitch_5 pitch_6  \
# 1414  001805b_            84      NO      NO      NO     YES      NO     YES
# 1415  001805b_            85      NO      NO     YES      NO      NO     YES
# 2904  004008b_            13     YES      NO      NO     YES      NO     YES
# 4371  014007b_            42     YES      NO      NO     YES      NO     YES
# 4372  014007b_            43      NO      NO      NO     YES      NO     YES
# 5052  014806bv             6     YES      NO      NO      NO      NO     YES
# 5053  014806bv             7     YES      NO      NO      NO     YES     YES
#
#      pitch_7 pitch_8 pitch_9 pitch_10 pitch_11 pitch_12 bass  meter  \
# 1414      NO      NO     YES       NO       NO       NO    F      3
# 1415      NO      NO     YES       NO       NO       NO    F      2
# 2904      NO      NO     YES       NO       NO       NO   Eb      3
# 4371      NO      NO     YES       NO       NO       NO    F      5
# 4372      NO     YES      NO       NO      YES       NO    F      2
# 5052      NO      NO     YES       NO       NO       NO    F      4
# 5053      NO      NO     YES       NO       NO       NO    F      2
#
#      chord_label
# 1414        F_m7
# 1415        F_m7
# 2904        F_m7
# 4371        F_m7
# 4372        F_m7
# 5052        F_m7
# 5053        F_m7

# %%
chord_labels = df.chord_label.unique()

# %%
def get_pitch_numbers(chord_label):
    return df.columns[(df[df['chord_label'] == chord_label].values=="YES")[0]].tolist()

chord_label_to_pitch_numbers = {}

for i in range(len(chord_labels)):
    chord_label_to_pitch_numbers[chord_labels[i]] = get_pitch_numbers(chord_labels[i])

# %%
chord_label_to_pitch_numbers
# Out:
# {'F_M': ['pitch_1', 'pitch_6', 'pitch_10'],
#  'C_M': ['pitch_1', 'pitch_5', 'pitch_8'],
#  'D_m': ['pitch_3', 'pitch_6', 'pitch_10'],
#  'BbM': ['pitch_3', 'pitch_6', 'pitch_11'],
#  'C_M7': ['pitch_5', 'pitch_8', 'pitch_10', 'pitch_11'],
#  'D_m7': ['pitch_1', 'pitch_3', 'pitch_6', 'pitch_10'],
#  'G_M': ['pitch_3', 'pitch_8', 'pitch_12'],
#  'A_m': ['pitch_1', 'pitch_5', 'pitch_10'],
#  'C_M4': ['pitch_1', 'pitch_6', 'pitch_8'],
#  'G_m': ['pitch_3', 'pitch_8', 'pitch_11'],
#  'G_M7': ['pitch_3', 'pitch_6', 'pitch_8', 'pitch_12'],
#  'D_M': ['pitch_3', 'pitch_7', 'pitch_10'],
#  'F#d': ['pitch_1', 'pitch_7', 'pitch_10'],
#  'AbM': ['pitch_1', 'pitch_4', 'pitch_9'],
#  'C#d7': ['pitch_2', 'pitch_5', 'pitch_8', 'pitch_11'],
#  'D_M7': ['pitch_1', 'pitch_3', 'pitch_7', 'pitch_10'],
#  'A_M': ['pitch_2', 'pitch_5', 'pitch_10'],
#  'EbM': ['pitch_4', 'pitch_8', 'pitch_11'],
#  'F_M7': ['pitch_1', 'pitch_4', 'pitch_8', 'pitch_10'],
#  'C_m': ['pitch_1', 'pitch_4', 'pitch_8'],
#  'A_M4': ['pitch_3', 'pitch_5', 'pitch_10'],
#  'F#m': ['pitch_2', 'pitch_7', 'pitch_10'],
#  'B_M': ['pitch_4', 'pitch_7', 'pitch_12'],
#  'E_M': ['pitch_5', 'pitch_9'],
#  'D#d': ['pitch_4', 'pitch_7', 'pitch_9', 'pitch_10'],
#  'C#M': ['pitch_2', 'pitch_7', 'pitch_9'],
#  'F#m7': ['pitch_3', 'pitch_5', 'pitch_9', 'pitch_12'],
#  'A#d': ['pitch_2', 'pitch_3', 'pitch_5', 'pitch_11'],
#  'B_m': ['pitch_3', 'pitch_7', 'pitch_12'],
#  'E_M7': ['pitch_3', 'pitch_5', 'pitch_9'],
#  'E_m': ['pitch_5', 'pitch_8', 'pitch_12'],
#  'F#M': ['pitch_2', 'pitch_7', 'pitch_11'],
#  'F#M7': ['pitch_2', 'pitch_5', 'pitch_7', 'pitch_11'],
#  'B_M7': ['pitch_4', 'pitch_7', 'pitch_10', 'pitch_12'],
#  'A_m6': ['pitch_1', 'pitch_5', 'pitch_7', 'pitch_10'],
#  'C#d': ['pitch_2', 'pitch_5', 'pitch_8'],
#  'A_m7': ['pitch_1', 'pitch_8', 'pitch_10'],
#  'A_d': ['pitch_1', 'pitch_4', 'pitch_10'],
#  'C_m7': ['pitch_1', 'pitch_4', 'pitch_8', 'pitch_11'],
#  'G_m6': ['pitch_4', 'pitch_8', 'pitch_11'],
#  'D_M4': ['pitch_3', 'pitch_8', 'pitch_10'],
#  'G_m7': ['pitch_3', 'pitch_6', 'pitch_8', 'pitch_11'],
#  'E_m7': ['pitch_3', 'pitch_5', 'pitch_8', 'pitch_12'],
#  'E_m6': ['pitch_2', 'pitch_5', 'pitch_8', 'pitch_12'],
#  'A_M7': ['pitch_2', 'pitch_5', 'pitch_8', 'pitch_10'],
#  'C#m': ['pitch_2', 'pitch_5', 'pitch_9'],
#  'C#M7': ['pitch_2', 'pitch_6', 'pitch_12'],
#  'A#d7': ['pitch_2', 'pitch_5', 'pitch_8', 'pitch_12'],
#  'EbM7': ['pitch_3', 'pitch_4', 'pitch_8'],
#  'B_m7': ['pitch_3', 'pitch_7', 'pitch_10', 'pitch_12'],
#  'E_M4': ['pitch_5', 'pitch_10', 'pitch_12'],
#  'C#m7': ['pitch_2', 'pitch_5', 'pitch_8', 'pitch_12'],
#  'F_M4': ['pitch_1', 'pitch_6', 'pitch_11'],
#  'D_m6': ['pitch_3', 'pitch_6', 'pitch_10', 'pitch_12'],
#  'G#d': ['pitch_3', 'pitch_9', 'pitch_12'],
#  'G#d7': ['pitch_3', 'pitch_6', 'pitch_9', 'pitch_12'],
#  'A_m4': ['pitch_3', 'pitch_5', 'pitch_10'],
#  'D_M6': ['pitch_3', 'pitch_7', 'pitch_10', 'pitch_12'],
#  'F_d': ['pitch_6', 'pitch_9', 'pitch_12'],
#  'B_m6': ['pitch_3', 'pitch_7', 'pitch_9', 'pitch_12'],
#  'B_M4': ['pitch_5', 'pitch_7', 'pitch_12'],
#  'C_m6': ['pitch_1', 'pitch_4', 'pitch_10'],
#  'F_m': ['pitch_1', 'pitch_6', 'pitch_9'],
#  'G_M4': ['pitch_1', 'pitch_3', 'pitch_8'],
#  'F_m7': ['pitch_4', 'pitch_6', 'pitch_9'],
#  'C_d6': ['pitch_1', 'pitch_4', 'pitch_7', 'pitch_10'],
#  'F_m6': ['pitch_1', 'pitch_3', 'pitch_6', 'pitch_9'],
#  'G_M6': ['pitch_3', 'pitch_5', 'pitch_8'],
#  'A_M6': ['pitch_2', 'pitch_5', 'pitch_7', 'pitch_10'],
#  'F_M6': ['pitch_3', 'pitch_6', 'pitch_10'],
#  'F#M4': ['pitch_2', 'pitch_7', 'pitch_12'],
#  'B_d7': ['pitch_3', 'pitch_6', 'pitch_8', 'pitch_12'],
#  'D_d7': ['pitch_3', 'pitch_6', 'pitch_9', 'pitch_12'],
#  'E_d': ['pitch_5', 'pitch_8', 'pitch_11'],
#  'Bbm': ['pitch_2', 'pitch_6', 'pitch_11'],
#  'Bbm6': ['pitch_2', 'pitch_6', 'pitch_8', 'pitch_11'],
#  'DbM': ['pitch_2', 'pitch_6', 'pitch_9'],
#  'C_d7': ['pitch_1', 'pitch_4', 'pitch_7', 'pitch_11'],
#  'F#d7': ['pitch_1', 'pitch_4', 'pitch_7', 'pitch_10'],
#  'Abd': ['pitch_3', 'pitch_9', 'pitch_12'],
#  'Ebd': ['pitch_4', 'pitch_7', 'pitch_10'],
#  'Dbd7': ['pitch_2', 'pitch_5', 'pitch_8', 'pitch_11'],
#  'Dbd': ['pitch_2', 'pitch_5', 'pitch_8'],
#  'Bbd': ['pitch_2', 'pitch_5', 'pitch_11'],
#  'Dbm7': ['pitch_2', 'pitch_5', 'pitch_9', 'pitch_12'],
#  'Abm': ['pitch_4', 'pitch_9', 'pitch_12'],
#  'DbM7': ['pitch_2', 'pitch_6', 'pitch_9', 'pitch_12'],
#  'Dbm': ['pitch_2', 'pitch_5', 'pitch_9'],
#  'F#m6': ['pitch_2', 'pitch_4', 'pitch_7', 'pitch_10'],
#  'G#m': ['pitch_4', 'pitch_9', 'pitch_12'],
#  'B_d': ['pitch_3', 'pitch_6', 'pitch_12'],
#  'C_M6': ['pitch_1', 'pitch_5', 'pitch_8', 'pitch_10'],
#  'D#m': ['pitch_4', 'pitch_7', 'pitch_9', 'pitch_11'],
#  'D#M': ['pitch_4', 'pitch_7', 'pitch_9', 'pitch_11'],
#  'BbM7': ['pitch_3', 'pitch_6', 'pitch_9', 'pitch_11'],
#  'F_d7': ['pitch_3', 'pitch_6', 'pitch_9', 'pitch_12'],
#  'C#d6': ['pitch_2', 'pitch_5', 'pitch_8', 'pitch_11'],
#  'G_d': ['pitch_2', 'pitch_8', 'pitch_11'],
#  'G#M': ['pitch_1', 'pitch_4', 'pitch_9'],
#  'C#M4': ['pitch_2', 'pitch_7', 'pitch_9', 'pitch_12'],
#  'D#d6': ['pitch_1', 'pitch_4', 'pitch_7', 'pitch_10'],
#  'D#d7': ['pitch_1', 'pitch_4', 'pitch_7', 'pitch_10']}

# %%
df.bass.unique()
# Out:
# array(['F', 'E', 'D', 'A', 'Bb', 'C', 'G', 'B', 'F#', 'C#', 'Eb', 'D#',
#        'G#', 'A#', 'Ab', 'Db'], dtype=object)

# %%
bach_chain = Chain()
bach_chain.build(first['chord_label'])

# %%
f1 = bach_chain.statetab

# %%
second = df[df['choral_ID'] == '000306b_']
bach_chain.build(second['chord_label'])

# %%
f2 = bach_chain.statetab

# %%
f1 == f2
# Out:
# True

# %%
df
# Out:
#      choral_ID  event_number pitch_1 pitch_2 pitch_3 pitch_4 pitch_5 pitch_6  \
# 0     000106b_             1     YES      NO      NO      NO      NO     YES
# 1     000106b_             2     YES      NO      NO      NO     YES      NO
# 2     000106b_             3     YES      NO      NO      NO     YES      NO
# 3     000106b_             4     YES      NO      NO      NO      NO     YES
# 4     000106b_             5     YES      NO      NO      NO      NO     YES
# 5     000106b_             6      NO      NO     YES      NO      NO     YES
# 6     000106b_             7      NO      NO     YES      NO      NO     YES
# 7     000106b_             8     YES      NO      NO      NO      NO     YES
# 8     000106b_             9     YES      NO      NO      NO      NO     YES
# 9     000106b_            10      NO      NO     YES      NO      NO     YES
# 10    000106b_            11      NO      NO     YES      NO      NO     YES
# 11    000106b_            12     YES      NO     YES      NO      NO     YES
# 12    000106b_            13     YES      NO     YES      NO      NO     YES
# 13    000106b_            14      NO      NO     YES      NO      NO     YES
# 14    000106b_            15      NO      NO     YES      NO     YES     YES
# 15    000106b_            16     YES      NO      NO      NO      NO     YES
# 16    000106b_            17     YES      NO      NO      NO      NO     YES
# 17    000106b_            18      NO      NO     YES      NO      NO     YES
# 18    000106b_            19      NO      NO     YES      NO      NO     YES
# 19    000106b_            20      NO      NO     YES      NO      NO     YES
# 20    000106b_            21      NO      NO      NO      NO     YES      NO
# 21    000106b_            22     YES      NO      NO      NO     YES      NO
# 22    000106b_            23      NO      NO      NO      NO     YES      NO
# 23    000106b_            24     YES      NO      NO      NO      NO     YES
# 24    000106b_            25      NO      NO     YES      NO      NO     YES
# 25    000106b_            26     YES      NO      NO      NO     YES      NO
# 26    000106b_            27     YES      NO      NO      NO     YES      NO
# 27    000106b_            28     YES      NO     YES      NO      NO     YES
# 28    000106b_            29      NO      NO     YES      NO     YES     YES
# 29    000106b_            30      NO      NO     YES      NO     YES     YES
# ...        ...           ...     ...     ...     ...     ...     ...     ...
# 5635  015505b_            80     YES      NO      NO      NO      NO     YES
# 5636  015505b_            81     YES      NO      NO      NO      NO     YES
# 5637  015505b_            82     YES      NO      NO      NO      NO     YES
# 5638  015505b_            83     YES      NO      NO      NO      NO     YES
# 5639  015505b_            84     YES      NO      NO      NO      NO     YES
# 5640  015505b_            85     YES      NO      NO      NO     YES      NO
# 5641  015505b_            86      NO      NO     YES      NO      NO     YES
# 5642  015505b_            87     YES      NO     YES      NO      NO     YES
# 5643  015505b_            88      NO      NO     YES      NO      NO     YES
# 5644  015505b_            89      NO      NO     YES      NO      NO     YES
# 5645  015505b_            90     YES      NO      NO      NO     YES      NO
# 5646  015505b_            91     YES      NO      NO      NO     YES      NO
# 5647  015505b_            92      NO      NO     YES      NO      NO      NO
# 5648  015505b_            93     YES      NO      NO      NO     YES      NO
# 5649  015505b_            94      NO      NO     YES      NO      NO      NO
# 5650  015505b_            95     YES      NO      NO      NO      NO     YES
# 5651  015505b_            96     YES      NO      NO      NO      NO     YES
# 5652  015505b_            97     YES      NO      NO      NO     YES      NO
# 5653  015505b_            98     YES      NO      NO      NO     YES      NO
# 5654  015505b_            99      NO      NO     YES      NO      NO     YES
# 5655  015505b_           100      NO      NO     YES      NO     YES      NO
# 5656  015505b_           101     YES      NO      NO      NO      NO     YES
# 5657  015505b_           102      NO      NO     YES      NO      NO     YES
# 5658  015505b_           103     YES      NO      NO      NO     YES      NO
# 5659  015505b_           104     YES      NO      NO      NO     YES     YES
# 5660  015505b_           105      NO      NO     YES      NO      NO      NO
# 5661  015505b_           106      NO      NO     YES      NO      NO      NO
# 5662  015505b_           107     YES      NO      NO      NO     YES      NO
# 5663  015505b_           108     YES      NO      NO      NO     YES      NO
# 5664  015505b_           109      NO      NO      NO      NO      NO     YES
#
#      pitch_7 pitch_8 pitch_9 pitch_10 pitch_11 pitch_12 bass  meter  \
# 0         NO      NO      NO      YES       NO       NO    F      3
# 1         NO     YES      NO       NO       NO       NO    E      5
# 2         NO     YES      NO       NO       NO       NO    E      2
# 3         NO      NO      NO      YES       NO       NO    F      3
# 4         NO      NO      NO      YES       NO       NO    F      2
# 5         NO      NO      NO      YES       NO       NO    D      4
# 6         NO      NO      NO      YES       NO       NO    D      2
# 7         NO      NO      NO      YES       NO       NO    A      3
# 8         NO      NO      NO      YES       NO       NO    A      2
# 9         NO      NO      NO       NO      YES       NO   Bb      5
# 10        NO      NO      NO       NO      YES       NO   Bb      1
# 11        NO      NO      NO      YES      YES       NO    C      2
# 12        NO     YES      NO       NO      YES       NO    C      1
# 13        NO      NO      NO       NO      YES       NO    D      3
# 14        NO     YES      NO       NO      YES       NO    E      2
# 15        NO      NO      NO      YES       NO       NO    F      4
# 16        NO      NO      NO      YES       NO       NO    F      3
# 17        NO      NO      NO       NO      YES       NO   Bb      5
# 18        NO     YES      NO       NO      YES       NO   Bb      2
# 19        NO      NO      NO      YES      YES       NO   Bb      1
# 20        NO     YES      NO      YES      YES       NO    A      3
# 21        NO     YES      NO       NO      YES       NO    G      2
# 22        NO     YES      NO       NO      YES       NO    G      1
# 23        NO      NO      NO      YES       NO       NO    A      4
# 24        NO     YES      NO       NO       NO      YES    B      2
# 25        NO     YES      NO       NO       NO       NO    C      3
# 26        NO     YES      NO       NO       NO       NO    C      2
# 27        NO      NO      NO      YES       NO       NO    F      5
# 28        NO      NO      NO      YES       NO      YES    F      2
# 29        NO      NO      NO      YES       NO       NO    F      1
# ...      ...     ...     ...      ...      ...      ...  ...    ...
# 5635      NO      NO      NO      YES       NO       NO    F      5
# 5636      NO     YES      NO       NO      YES       NO    F      3
# 5637      NO      NO      NO      YES       NO       NO    F      4
# 5638      NO     YES      NO       NO      YES       NO    G      3
# 5639      NO      NO      NO      YES       NO       NO    A      5
# 5640      NO     YES      NO      YES       NO       NO    A      3
# 5641      NO      NO      NO       NO      YES       NO   Bb      4
# 5642      NO      NO      NO       NO       NO       NO    C      3
# 5643      NO      NO      NO      YES       NO       NO    D      5
# 5644      NO      NO      NO       NO      YES       NO    D      3
# 5645      NO     YES      NO       NO       NO       NO    E      4
# 5646     YES      NO      NO      YES       NO       NO   F#      3
# 5647      NO     YES      NO       NO      YES       NO    G      5
# 5648      NO     YES      NO       NO      YES       NO    G      3
# 5649     YES      NO      NO      YES       NO       NO    D      4
# 5650      NO      NO      NO      YES       NO       NO    A      5
# 5651      NO      NO      NO      YES      YES       NO   Bb      3
# 5652      NO     YES      NO       NO       NO       NO    C      4
# 5653      NO      NO      NO      YES       NO       NO    C      3
# 5654      NO      NO      NO       NO      YES       NO    D      5
# 5655      NO     YES      NO       NO      YES       NO    E      3
# 5656      NO      NO      NO      YES       NO       NO    F      4
# 5657      NO      NO      NO      YES      YES       NO    F      3
# 5658      NO     YES      NO       NO       NO       NO    E      5
# 5659      NO     YES      NO       NO       NO       NO    F      3
# 5660      NO     YES      NO       NO      YES       NO    G      4
# 5661      NO     YES      NO      YES       NO       NO    G      3
# 5662      NO     YES      NO       NO       NO       NO    C      5
# 5663      NO     YES      NO       NO      YES       NO    C      3
# 5664      NO      NO      NO      YES       NO       NO    F      4
#
#      chord_label
# 0            F_M
# 1            C_M
# 2            C_M
# 3            F_M
# 4            F_M
# 5            D_m
# 6            D_m
# 7            F_M
# 8            F_M
# 9            BbM
# 10           BbM
# 11           BbM
# 12           BbM
# 13           BbM
# 14           BbM
# 15           F_M
# 16           F_M
# 17           BbM
# 18           BbM
# 19           BbM
# 20          C_M7
# 21          C_M7
# 22          C_M7
# 23           F_M
# 24           F_M
# 25           C_M
# 26           C_M
# 27          D_m7
# 28          D_m7
# 29          D_m7
# ...          ...
# 5635         F_M
# 5636         F_M
# 5637         F_M
# 5638         F_M
# 5639         F_M
# 5640         F_M
# 5641         BbM
# 5642         BbM
# 5643         D_m
# 5644         D_m
# 5645         C_M
# 5646         C_M
# 5647         G_m
# 5648         G_m
# 5649         D_M
# 5650         F_M
# 5651         F_M
# 5652         C_M
# 5653         C_M
# 5654         BbM
# 5655         BbM
# 5656         F_M
# 5657         F_M
# 5658         C_M
# 5659         C_M
# 5660         G_m
# 5661         G_m
# 5662         C_M
# 5663         C_M
# 5664         F_M
#
# [5665 rows x 17 columns]
